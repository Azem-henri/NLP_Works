# %% [markdown]
# # Terminology and Ontology Project
#
# By
#
# ---- Henri Joël Azemena   azemehenri@gmail.com / azemena1u@etu.univ-lorraine.fr
#
# ---- Guillaume Richez    guillaume.richez9@etu.univ-lorraine.fr / guillaume.richez9@etu.univ-lorraine.fr
#
# ---- Goal : develop a term identification system for a specific domain.
#
# ---- Chosen domain: Natural Language Generation
#
# ---- Tools: Linux, Python 3.9, Spacy, textract, os, string, nltk, __future__,plac, random, pathlib, tqdm

# %% [markdown]
# ### Importing the libraries

# %%
from os import listdir
import textract
import string 
from nltk import word_tokenize
import spacy
from spacy.matcher import Matcher
from nltk import word_tokenize
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
from tqdm import tqdm 
from spacy.training.example import Example

# %% [markdown]
# ## Function that will extract automatically the text  from the set of articles

# %%
def extract_articles_content(path):
    texts = ""
    for file in listdir(path):
        paper = path + file
        if paper != path + '.DS_Store':
            text = textract.process(paper, method='pdfminer',encoding='UTF-8')
            text = text.decode("utf-8") 
            texts = texts + text
        
    return texts

# %% [markdown]
# ## Creation of our Corpora from the  20  articles in a NLG domain

# %%
corpora = extract_articles_content("path_to_the_scientific_articles_folder")

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Function we use to  clean the corpora

# %%
def clean_corpora(text_set):
    text_set = text_set.replace('\n' , ' ')
    text_set = text_set.replace('- ' , '')
    text_set = text_set.lower()
    
    #remove punctuation
    
    tokens = word_tokenize(text_set)
    for i,word in enumerate(tokens):
        if 'https' in word or '\\uf' in word:
            del tokens[i]
        if 'hal' in word:
            del tokens[i]
        if 'cid' in word or '¥' in word or '¢' in word:
            del tokens[i]
        if len(word)==1 and word != 'a':
            del tokens[i]
    
    text_set = ' '.join(tokens)
    return text_set

# %% [markdown]
# ## Clean and save the corpora

# %%
corpora = clean_corpora(corpora)

with open('corpora.txt','w') as file:
    file.write(corpora)

# %% [markdown]
# # Implementation of our SILVER and definition of patterns

# %%
nlp = spacy.load("en_core_web_sm")
corpora = nlp(corpora)
matcher = Matcher(nlp.vocab)
terms = []
patterns = [[{"POS": "NOUN"}],[{"POS": "NOUN"},{"POS": "NOUN"}],[{"POS": "ADJ"},{"POS": "NOUN"}],[{"POS": "NOUN"},{"POS": "ADJ"}],[{"POS": "NOUN"},{"POS": "ADP"},{"POS": "NOUN"}],
           [{"POS": "NOUN"},{"POS": "ADP"},{"POS": "DET"},{"POS": "NOUN"}],[{"POS": "NOUN"},{"POS": "NOUN"},{"POS": "NOUN"}]]
matcher.add("Compound nouns", patterns)
matches = matcher(corpora)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  
    span = corpora[start:end] 
    terms.append(span.text)

# %% [markdown]
# ## Clean and save the Silver after manual filterring

# %%
def remove_useless(text_set):
    result = x
    for i,word in enumerate(x):
        if len(word_tokenize(word)) <= 4 or 'CSV' in word or '%' in word:
            del result[i]
        #remove all word with numbers
        if any(char.isdigit() for char in word):
            del result[i]
        if 'CSV Q' in word:
            del result[i]
            
    return result

silver = remove_useless(terms)
silver = set(silver)

# %%
def cleaning_terms(l):
    new_l = [term for term in l if len(term) >= 4 if 'csv' not in term.lower() if '%' not in term.lower()]
    new_l = [term for term in new_l if any(i.isdigit() for i in term) == False]
    new_l = [term for term in new_l if any(token for token in term.split() if len(token) < 2 if len(term) < 10) == False]
    return new_l

len(cleaning_terms(silver))

with open('silver.txt','w') as file:
    for i in silver:
        file.write(i+'\n')

# %% [markdown]
# ## Load the filter SILVER

# %%
silver = []
with open('silver.txt') as file:
    lines = file.readlines()
    
    for line in lines :
        silver.append(line)
silver = [x[:-1] for x in silver]

# %% [markdown]
# ## Load the copora

# %%
with open('corpora.txt') as file:
    corpora = file.readlines()

corpus = corpus[0]

# %% [markdown]
# ## Creation of IBO finction for automatic ananotation

# %%
def annot(text, silver):
    tokens = word_tokenize(text)
    #print(tokens)
    offset = 0
    entities = []
    i = 0
    while i < (len(tokens)):
        offset = text.find(tokens[i], offset)
        if i < len(tokens) - 3 and " ".join(tokens[i:i+3]) in silver:
            entities.append((offset,offset+len(tokens[i]),'B'))
            entities.append((offset+len(tokens[i])+1,offset+len(tokens[i])+len(tokens[i+1])+1,'I'))
            entities.append((offset+len(tokens[i])+len(tokens[i+1])+2,offset+len(tokens[i])+len(tokens[i+1])+len(tokens[i+2])+2,'I'))
            i = i+3
            #offset=offset+len(tokens[i])+len(tokens[i+1])+len(tokens[i+2])
        elif i < len(tokens) - 2 and " ".join(tokens[i:i+2]) in silver:
            entities.append((offset,offset+len(tokens[i]),'B'))
            entities.append((offset+len(tokens[i])+1,offset+len(tokens[i])+len(tokens[i+1])+2,'I'))
            i = i+2 
            #offset=offset+len(tokens[i])+len(tokens[i+1])
        elif i < len(tokens) - 1 and tokens[i] in silver:
            entities.append((offset,offset+len(tokens[i]),'B'))
            i = i+1
            #offset=offset+len(tokens[i])
        else:
            entities.append((offset,offset+len(tokens[i]),'O'))
            i = i+1
        offset = entities[-1][1]
    return {'entities': entities}

# %% [markdown]
# ## Annotation of the corpora using the filter SILVER

# %%
tokens = word_tokenize(corpora)
TRAIN_DATA = []
for i in range(0,len(tokens),20):
    text = " ".join(tokens[i:i+20])
    TRAIN_DATA.append((text, annot(text, silver)))

# %% [markdown]
# ## Saving the training set

# %%
with open('traindata.txt','w') as file:
    for a, annotations in TRAIN_DATA:
        record = "'"+a + "'," + str(annotations) +'\n'
        file.write(record)

# %% [markdown]
# # NER setting using Spacy

# %% [markdown]
# ## Creation of our Model

# %%
model_ner = None
output_dir=Path("path_to_the_folder_where_we want_to_save_the_model")
n_iter=150

# %%
if model_ner is not None:
    nlp = spacy.load(model_ner)  
    print("Loaded model '%s'" % model_ner)
else:
    nlp = spacy.blank('en')  
    print("Created blank 'en' model_ner")
# Out:
# Created blank 'en' model

# %%
if "ner" not in nlp.pipe_names:
        #ner = nlp.create_pipe("ner")
        ner = nlp.add_pipe("ner", last=True)
    # otherwise, get it so we can add labels
else:
        ner = nlp.get_pipe("ner")

# %% [markdown]
# ## Training of our model

# %%
for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in tqdm(TRAIN_DATA):
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, annotations)
            nlp.update(
                [example],  
                drop=0.5,  
                sgd=optimizer,
                losses=losses)
        print(losses)
# Out:
#   0%|          | 1/2209 [00:00<03:57,  9.29it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "recognition asr errors and out-of-vocabulary oov p..." with entities "[(0, 11, 'B'), (12, 15, 'B'), (16, 23, 'I'), (23, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   0%|          | 5/2209 [00:00<02:16, 16.14it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "pluridisciplinaire est destinée au dépôt et la dif..." with entities "[(0, 18, 'B'), (19, 22, 'O'), (23, 31, 'O'), (32, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the segment corresponding to the sequence is proce..." with entities "[(0, 3, 'O'), (4, 11, 'B'), (12, 25, 'O'), (26, 28...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   0%|          | 7/2209 [00:00<02:11, 16.72it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "describe the construction of the data sets and the..." with entities "[(0, 8, 'O'), (9, 12, 'O'), (13, 25, 'B'), (26, 28...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   0%|          | 10/2209 [00:00<01:56, 18.85it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "order to control the data and facilitate the extra..." with entities "[(0, 5, 'O'), (6, 8, 'O'), (9, 16, 'B'), (17, 20, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   1%|          | 15/2209 [00:00<01:47, 20.35it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "model rescoring rover-style system combination is ..." with entities "[(0, 5, 'B'), (6, 15, 'O'), (16, 27, 'O'), (28, 34...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "sample that will allow the detection of the same p..." with entities "[(0, 6, 'B'), (7, 11, 'O'), (12, 16, 'O'), (17, 22...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   1%|          | 18/2209 [00:00<01:49, 19.99it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "on well-written texts retraining asr language mode..." with entities "[(0, 2, 'O'), (3, 15, 'O'), (16, 21, 'B'), (22, 32...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   1%|          | 21/2209 [00:01<01:46, 20.53it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "and then uses a support vector machine svm to trai..." with entities "[(0, 3, 'O'), (4, 8, 'O'), (9, 13, 'B'), (14, 15, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   1%|          | 24/2209 [00:01<01:48, 20.08it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "of training and the tests 3838 and 1913 vowel inst..." with entities "[(0, 2, 'O'), (3, 11, 'B'), (12, 15, 'O'), (16, 19...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   1%|▏         | 30/2209 [00:01<01:50, 19.69it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "continual improvement of ner performance the optim..." with entities "[(0, 9, 'O'), (10, 21, 'B'), (22, 24, 'O'), (25, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "user voice anonymization will make such adaptation..." with entities "[(0, 4, 'B'), (5, 10, 'B'), (11, 25, 'I'), (25, 29...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   1%|▏         | 32/2209 [00:01<01:54, 19.04it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "procedure proposed by bocchieri 1993 and described..." with entities "[(0, 9, 'B'), (10, 18, 'O'), (19, 21, 'O'), (22, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   2%|▏         | 44/2209 [00:02<02:23, 15.05it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "both asr and v2x communication systems lkj pasr ck..." with entities "[(0, 4, 'O'), (5, 8, 'B'), (9, 12, 'O'), (13, 16, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   2%|▏         | 50/2209 [00:02<02:04, 17.27it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "table iv also shows the results when auditory para..." with entities "[(0, 5, 'B'), (6, 8, 'O'), (9, 13, 'O'), (14, 19, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   2%|▏         | 52/2209 [00:03<02:17, 15.68it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "train neural detector with fast features of sample..." with entities "[(0, 5, 'B'), (6, 12, 'B'), (13, 22, 'I'), (22, 26...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   2%|▏         | 54/2209 [00:03<02:11, 16.44it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "eight parameters in all was extracted for modellin..." with entities "[(0, 5, 'O'), (6, 16, 'B'), (17, 19, 'O'), (20, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "beamforming and non negative matrix factorization ..." with entities "[(0, 11, 'B'), (12, 15, 'O'), (16, 19, 'O'), (20, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   3%|▎         | 64/2209 [00:03<02:02, 17.50it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "with 50 overlapping mel-frequency cepstral coefﬁci..." with entities "[(0, 4, 'O'), (5, 7, 'O'), (8, 19, 'B'), (20, 33, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   3%|▎         | 66/2209 [00:03<02:04, 17.26it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "dramatically different the loss function of the fa..." with entities "[(0, 12, 'O'), (13, 22, 'B'), (23, 26, 'O'), (27, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   3%|▎         | 73/2209 [00:04<02:06, 16.95it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "recognition the emission likelihood of multi-strea..." with entities "[(0, 11, 'B'), (12, 15, 'O'), (16, 24, 'B'), (25, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "space voice casting raises two issues over speaker..." with entities "[(0, 5, 'B'), (6, 11, 'B'), (12, 20, 'I'), (20, 26...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   4%|▎         | 79/2209 [00:04<02:06, 16.80it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "on improvements to ci based gmm selection european..." with entities "[(0, 2, 'O'), (3, 15, 'B'), (16, 18, 'O'), (19, 21...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   4%|▎         | 81/2209 [00:04<02:03, 17.21it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "project phone for deaf people aims at developing a..." with entities "[(0, 7, 'O'), (8, 13, 'B'), (14, 17, 'O'), (18, 22...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "correlation there are many outlying systems for wh..." with entities "[(0, 11, 'B'), (12, 17, 'O'), (18, 21, 'O'), (22, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   4%|▍         | 86/2209 [00:05<01:51, 18.97it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "experiments 53 gaussians in which only 20 of the i..." with entities "[(0, 11, 'B'), (12, 14, 'O'), (15, 24, 'B'), (25, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   4%|▍         | 88/2209 [00:05<01:53, 18.64it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the vocal sounds process tool `` praat `` to achie..." with entities "[(0, 3, 'O'), (4, 9, 'O'), (10, 16, 'B'), (17, 24,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   4%|▍         | 95/2209 [00:05<02:03, 17.16it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the recorded samples and the seed samples the numb..." with entities "[(0, 3, 'O'), (4, 12, 'O'), (13, 20, 'B'), (21, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   5%|▍         | 101/2209 [00:05<02:01, 17.36it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "which uses eight handshapes in ﬁve different posit..." with entities "[(0, 5, 'O'), (6, 10, 'B'), (11, 16, 'O'), (17, 27...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "drivers /passengers conversational speech and clas..." with entities "[(0, 7, 'B'), (8, 19, 'B'), (20, 34, 'B'), (35, 42...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   5%|▌         | 112/2209 [00:06<01:49, 19.23it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "acoustic model training resulted in a clear beneﬁt..." with entities "[(0, 8, 'B'), (9, 15, 'I'), (15, 23, 'B'), (24, 32...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "in proceedings of the annual conference of the int..." with entities "[(0, 2, 'O'), (3, 14, 'B'), (15, 17, 'O'), (18, 21...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   6%|▌         | 122/2209 [00:07<01:58, 17.68it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "lipreading technique speech can be understood by i..." with entities "[(0, 10, 'B'), (11, 21, 'I'), (21, 27, 'B'), (28, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "integration of available single modality streams i..." with entities "[(0, 11, 'B'), (12, 14, 'O'), (15, 24, 'O'), (25, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   6%|▌         | 124/2209 [00:07<02:28, 14.01it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "example spatial coherence ﬁltering 32 41 or ﬁlteri..." with entities "[(0, 7, 'B'), (8, 16, 'I'), (16, 25, 'B'), (26, 34...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   6%|▌         | 126/2209 [00:07<02:22, 14.62it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "and technology 1996 10911094 lee a. kawahara t. ta..." with entities "[(0, 3, 'O'), (4, 14, 'B'), (15, 19, 'O'), (20, 28...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   6%|▌         | 136/2209 [00:08<02:06, 16.38it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "method outperforms svq-a using only one stream is ..." with entities "[(0, 6, 'O'), (7, 18, 'B'), (19, 24, 'O'), (25, 30...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   7%|▋         | 149/2209 [00:08<01:43, 19.89it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "gaussians they are sorted by weight and only the g..." with entities "[(0, 9, 'B'), (10, 14, 'O'), (15, 18, 'O'), (19, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   7%|▋         | 153/2209 [00:08<01:50, 18.55it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "units are derived from 39 phonemes of english and ..." with entities "[(0, 5, 'B'), (6, 9, 'O'), (10, 17, 'O'), (18, 22,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   7%|▋         | 157/2209 [00:09<01:58, 17.33it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "are promising references a. a. montgomery and p. j..." with entities "[(0, 3, 'O'), (4, 13, 'O'), (14, 24, 'B'), (25, 27...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   8%|▊         | 169/2209 [00:09<01:55, 17.65it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "morphology were extracted the pinching of the uppe..." with entities "[(0, 10, 'B'), (11, 15, 'O'), (16, 25, 'O'), (26, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   8%|▊         | 179/2209 [00:11<04:15,  7.96it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "quality computed on the devpart corpus figure show..." with entities "[(0, 7, 'B'), (8, 16, 'O'), (17, 19, 'O'), (20, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   8%|▊         | 181/2209 [00:11<03:30,  9.64it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the hands of big corporations dramatic improvement..." with entities "[(0, 3, 'O'), (4, 9, 'B'), (10, 12, 'O'), (13, 16,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   9%|▊         | 193/2209 [00:12<02:12, 15.20it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "stressed surprise other action conversation inform..." with entities "[(0, 8, 'O'), (9, 17, 'B'), (18, 23, 'O'), (24, 30...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   9%|▉         | 195/2209 [00:12<02:15, 14.88it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "improvement of 28.4 was obtained the results showe..." with entities "[(0, 11, 'B'), (12, 14, 'O'), (15, 19, 'O'), (20, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   9%|▉         | 197/2209 [00:12<02:10, 15.36it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "integrating asr and ner processes allows the asr s..." with entities "[(0, 11, 'O'), (12, 15, 'B'), (16, 19, 'O'), (20, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   9%|▉         | 205/2209 [00:13<02:27, 13.62it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "product hmms for robust in proceedings of fourth i..." with entities "[(0, 7, 'O'), (8, 12, 'B'), (13, 16, 'O'), (17, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#   9%|▉         | 209/2209 [00:13<02:12, 15.04it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "of diagonal mixture gaussians international confer..." with entities "[(0, 2, 'O'), (3, 11, 'O'), (12, 19, 'B'), (20, 29...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  10%|▉         | 211/2209 [00:13<02:12, 15.10it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "training and test sets are distinct some overlap i..." with entities "[(0, 8, 'B'), (9, 12, 'O'), (13, 17, 'B'), (18, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  10%|▉         | 213/2209 [00:13<02:08, 15.49it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "conference on acoustics speech and signal processi..." with entities "[(0, 10, 'B'), (11, 13, 'O'), (14, 23, 'B'), (24, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  10%|▉         | 219/2209 [00:13<01:54, 17.32it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "process because they can be a viable option when r..." with entities "[(0, 7, 'B'), (8, 15, 'O'), (16, 20, 'O'), (21, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  10%|█         | 222/2209 [00:14<01:45, 18.82it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "and research institutions in france or abroad or f..." with entities "[(0, 3, 'O'), (4, 12, 'B'), (13, 25, 'O'), (26, 28...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  10%|█         | 226/2209 [00:14<01:50, 17.97it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "in either case the convolved speech signal is resc..." with entities "[(0, 2, 'O'), (3, 9, 'O'), (10, 14, 'B'), (15, 18,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  10%|█         | 228/2209 [00:14<01:53, 17.50it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "vector olh rd is the joint lip-hand feature vector..." with entities "[(0, 6, 'B'), (7, 10, 'O'), (11, 13, 'O'), (14, 16...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  11%|█         | 237/2209 [00:14<01:43, 19.02it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "processing denver co 2002 pp 25-28. feature in pro..." with entities "[(0, 10, 'B'), (11, 17, 'O'), (18, 20, 'O'), (21, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  11%|█         | 247/2209 [00:15<01:44, 18.83it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "shown in table i. to investigate the impact of the..." with entities "[(0, 5, 'O'), (6, 8, 'O'), (9, 14, 'B'), (15, 17, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  11%|█▏        | 251/2209 [00:15<01:53, 17.27it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "techniques will also normalizing environment varia..." with entities "[(0, 10, 'B'), (11, 15, 'O'), (16, 20, 'O'), (21, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  11%|█▏        | 253/2209 [00:15<01:54, 17.08it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "distributions and the corresponding cd distributio..." with entities "[(0, 13, 'B'), (14, 17, 'O'), (18, 21, 'O'), (22, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  12%|█▏        | 255/2209 [00:15<01:56, 16.73it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "hidden markov model ieee transactions on speech an..." with entities "[(0, 6, 'B'), (7, 14, 'I'), (14, 19, 'B'), (20, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  12%|█▏        | 257/2209 [00:15<01:57, 16.59it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "25 19 a generalization of this approach consists i..." with entities "[(0, 2, 'O'), (3, 5, 'O'), (6, 7, 'O'), (8, 22, 'B...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  12%|█▏        | 267/2209 [00:16<02:08, 15.06it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "hours for language model we use cantab language mo..." with entities "[(0, 5, 'B'), (6, 9, 'O'), (10, 18, 'B'), (19, 25,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "majority of the following instrumental techniques ..." with entities "[(0, 8, 'B'), (9, 11, 'O'), (12, 15, 'O'), (16, 25...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  12%|█▏        | 269/2209 [00:16<02:08, 15.11it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "matrix was used all 24 pca lip shape components we..." with entities "[(0, 6, 'B'), (7, 10, 'O'), (11, 15, 'O'), (16, 19...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "of the language clustering of recorded samples nee..." with entities "[(0, 2, 'O'), (3, 6, 'O'), (7, 15, 'B'), (16, 26, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  12%|█▏        | 271/2209 [00:16<02:07, 15.22it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "to the distance to the center of the microphone ar..." with entities "[(0, 2, 'O'), (3, 6, 'O'), (7, 15, 'B'), (16, 18, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "different access categories acs based on the impor..." with entities "[(0, 9, 'B'), (10, 16, 'B'), (17, 27, 'B'), (28, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  13%|█▎        | 279/2209 [00:17<02:33, 12.54it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "everyday environments remains a goal the series of..." with entities "[(0, 8, 'O'), (9, 21, 'B'), (22, 29, 'O'), (30, 31...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  13%|█▎        | 281/2209 [00:17<02:29, 12.87it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "evaluate our approach 16 broadcasts 5. integrating..." with entities "[(0, 8, 'O'), (9, 12, 'O'), (13, 21, 'B'), (22, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  13%|█▎        | 291/2209 [00:18<02:44, 11.63it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "techniques which can exploit stereo pairing betwee..." with entities "[(0, 10, 'B'), (11, 16, 'O'), (17, 20, 'O'), (21, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  14%|█▎        | 299/2209 [00:18<01:53, 16.77it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "émanant des établissements enseignement et de rech..." with entities "[(0, 7, 'O'), (8, 11, 'O'), (12, 26, 'B'), (27, 39...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  14%|█▎        | 301/2209 [00:19<01:53, 16.86it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "adaptive-bk inter-car distance hand in adaptive st..." with entities "[(0, 11, 'O'), (12, 21, 'O'), (22, 30, 'B'), (31, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  14%|█▍        | 305/2209 [00:19<02:10, 14.61it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "noise reduction in proc ieee asru 2015 25 t. t. vu..." with entities "[(0, 5, 'B'), (6, 15, 'B'), (16, 18, 'O'), (19, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  14%|█▍        | 309/2209 [00:19<02:20, 13.56it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "test phoneme-to-viseme mapping in the french langu..." with entities "[(0, 4, 'B'), (5, 22, 'O'), (23, 30, 'B'), (31, 33...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  14%|█▍        | 317/2209 [00:20<02:17, 13.76it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "hypotheses with a different number of words when w..." with entities "[(0, 10, 'B'), (11, 15, 'O'), (16, 17, 'O'), (18, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  15%|█▍        | 327/2209 [00:21<02:23, 13.11it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "privacy-transformed data baseline asr training dat..." with entities "[(0, 19, 'O'), (20, 24, 'B'), (25, 33, 'B'), (34, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  15%|█▍        | 329/2209 [00:21<03:05, 10.15it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "a means to create new speech databases for trainin..." with entities "[(0, 1, 'O'), (2, 7, 'B'), (8, 10, 'O'), (11, 17, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  15%|█▍        | 331/2209 [00:21<02:54, 10.76it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "one feature that is not yet possible with the latt..." with entities "[(0, 3, 'O'), (4, 11, 'B'), (12, 16, 'O'), (17, 19...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  15%|█▌        | 335/2209 [00:21<02:28, 12.60it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "research on training of the asr acoustic models on..." with entities "[(0, 8, 'B'), (9, 11, 'O'), (12, 20, 'B'), (21, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "in proceedings of the 14th annual conference of th..." with entities "[(0, 2, 'O'), (3, 14, 'B'), (15, 17, 'O'), (18, 21...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  15%|█▌        | 339/2209 [00:22<02:34, 12.12it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "in the following the performance of the contextual..." with entities "[(0, 2, 'O'), (3, 6, 'O'), (7, 16, 'B'), (17, 20, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▌        | 345/2209 [00:22<02:44, 11.30it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "smbr criterion 17 this second baseline requires a ..." with entities "[(0, 4, 'O'), (5, 14, 'B'), (15, 17, 'O'), (18, 22...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▌        | 349/2209 [00:22<02:37, 11.79it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "threats to the users this resulted in a growth of ..." with entities "[(0, 7, 'B'), (8, 10, 'O'), (11, 14, 'O'), (15, 20...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▌        | 351/2209 [00:23<02:26, 12.64it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "then ﬁlterbank features for the dnn pass most syst..." with entities "[(0, 4, 'O'), (5, 14, 'O'), (15, 23, 'B'), (24, 27...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▌        | 353/2209 [00:23<02:16, 13.57it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the linguistic scores of the new word-graphs using..." with entities "[(0, 3, 'O'), (4, 14, 'O'), (15, 21, 'B'), (22, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▌        | 355/2209 [00:23<02:12, 14.02it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "using privacy-transformed speech in the automatic ..." with entities "[(0, 5, 'O'), (6, 25, 'O'), (26, 32, 'B'), (33, 35...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▌        | 357/2209 [00:23<02:10, 14.22it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "simulation algorithms and either replace or augmen..." with entities "[(0, 10, 'B'), (11, 21, 'B'), (22, 25, 'O'), (26, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  16%|█▋        | 361/2209 [00:23<02:05, 14.67it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "corpus which is used to adjust some parameters 10 ..." with entities "[(0, 6, 'B'), (7, 12, 'O'), (13, 15, 'O'), (16, 20...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# ...
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  98%|█████████▊| 2160/2209 [02:34<00:03, 15.36it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the reference samples needed for clustering the se..." with entities "[(0, 3, 'O'), (4, 13, 'B'), (14, 21, 'B'), (22, 28...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the criterion and varied the distance in this para..." with entities "[(0, 3, 'O'), (4, 13, 'B'), (14, 17, 'O'), (18, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  98%|█████████▊| 2162/2209 [02:34<00:02, 15.81it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "have potential to elicit focused scientiﬁc ﬁndings..." with entities "[(0, 4, 'O'), (5, 14, 'B'), (15, 17, 'O'), (18, 24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  98%|█████████▊| 2164/2209 [02:34<00:02, 16.43it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "standard procedure pre-training using restricted b..." with entities "[(0, 8, 'O'), (9, 18, 'B'), (19, 31, 'O'), (32, 37...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  98%|█████████▊| 2166/2209 [02:34<00:02, 16.03it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "along the speaker basis and is a residual vector w..." with entities "[(0, 5, 'O'), (6, 9, 'O'), (10, 17, 'B'), (18, 23,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  98%|█████████▊| 2168/2209 [02:35<00:02, 16.19it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "effectiveness of the proposed approaches to cued s..." with entities "[(0, 13, 'B'), (14, 16, 'O'), (17, 20, 'O'), (21, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  98%|█████████▊| 2170/2209 [02:35<00:02, 16.30it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "clustering and gaussian selection in this paper we..." with entities "[(0, 10, 'B'), (11, 14, 'O'), (15, 23, 'B'), (24, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▊| 2176/2209 [02:35<00:02, 14.26it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "segments leading to the same vector a nt equivocat..." with entities "[(0, 8, 'B'), (9, 16, 'O'), (17, 19, 'O'), (20, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▊| 2180/2209 [02:35<00:02, 14.34it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "the contribution of our system to sustainability c..." with entities "[(0, 3, 'O'), (4, 16, 'B'), (17, 19, 'O'), (20, 23...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "system again optimizing this completely neural bas..." with entities "[(0, 6, 'B'), (7, 12, 'O'), (13, 23, 'O'), (24, 28...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▉| 2184/2209 [02:36<00:01, 15.51it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "its services we deﬁne the overall expected average..." with entities "[(0, 3, 'O'), (4, 12, 'B'), (13, 15, 'O'), (16, 21...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▉| 2186/2209 [02:36<00:01, 13.22it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "recognition in proc ieee asru 2015 20 j. du q. wan..." with entities "[(0, 11, 'B'), (12, 14, 'O'), (15, 19, 'O'), (20, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▉| 2188/2209 [02:36<00:01, 13.56it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "entities are not annotated in the annotated vocabu..." with entities "[(0, 8, 'B'), (9, 12, 'O'), (13, 16, 'O'), (17, 26...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▉| 2190/2209 [02:36<00:01, 14.26it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "model g. probability g|y nt can be computed by ass..." with entities "[(0, 5, 'B'), (6, 8, 'O'), (9, 20, 'B'), (21, 24, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▉| 2192/2209 [02:36<00:01, 14.75it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "for integrating probabilities provided by acoustic..." with entities "[(0, 3, 'O'), (4, 15, 'O'), (16, 29, 'B'), (30, 38...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "g. gravier a. garg and a.w senior recent in advanc..." with entities "[(0, 2, 'O'), (3, 10, 'B'), (11, 13, 'O'), (14, 18...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
#  99%|█████████▉| 2196/2209 [02:37<00:00, 13.60it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "data were derived from a video recording of the sp..." with entities "[(0, 4, 'B'), (5, 9, 'O'), (10, 17, 'O'), (18, 22,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# 100%|█████████▉| 2198/2209 [02:37<00:00, 13.14it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "estimate the noise signal by subtracting the convo..." with entities "[(0, 8, 'O'), (9, 12, 'O'), (13, 18, 'B'), (19, 25...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# 100%|█████████▉| 2202/2209 [02:37<00:00, 14.15it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "lips consonant group modality lips+shape group1 gr..." with entities "[(0, 4, 'B'), (5, 14, 'O'), (15, 20, 'O'), (21, 29...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "improved recognition the computation of gps global..." with entities "[(0, 8, 'O'), (9, 20, 'B'), (21, 24, 'O'), (25, 36...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# 100%|█████████▉| 2204/2209 [02:37<00:00, 14.50it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "analysis for inferences about identity in ieee int..." with entities "[(0, 8, 'B'), (9, 12, 'O'), (13, 23, 'B'), (24, 29...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# 100%|█████████▉| 2206/2209 [02:37<00:00, 14.58it/s]/Users/lasirene/opt/anaconda3/lib/python3.7/site-packages/spacy/training/iob_utils.py:142: UserWarning: [W030] Some entities could not be aligned in the text "14 another discriminative approach to automatic sp..." with entities "[(0, 2, 'O'), (3, 10, 'O'), (11, 25, 'B'), (26, 34...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# 100%|██████████| 2209/2209 [02:37<00:00, 13.98it/s]
#   0%|          | 2/2209 [00:00<02:29, 14.73it/s]
# {'ner': 10673.924832065906}
# 100%|██████████| 2209/2209 [01:51<00:00, 19.85it/s]
#   0%|          | 2/2209 [00:00<02:01, 18.16it/s]
# {'ner': 6273.9614340944545}
# 100%|██████████| 2209/2209 [01:51<00:00, 19.86it/s]
#   0%|          | 2/2209 [00:00<02:17, 16.07it/s]
# {'ner': 5290.906506937412}
# 100%|██████████| 2209/2209 [01:45<00:00, 20.94it/s]
#   0%|          | 2/2209 [00:00<02:02, 17.99it/s]
# {'ner': 4980.222842961371}
# 100%|██████████| 2209/2209 [01:41<00:00, 21.67it/s]
#   0%|          | 3/2209 [00:00<01:52, 19.61it/s]
# {'ner': 4424.863197846076}
# 100%|██████████| 2209/2209 [01:41<00:00, 21.83it/s]
#   0%|          | 3/2209 [00:00<01:42, 21.55it/s]
# {'ner': 4137.504696947721}
# 100%|██████████| 2209/2209 [01:42<00:00, 21.62it/s]
#   0%|          | 2/2209 [00:00<02:02, 18.03it/s]
# {'ner': 3944.081666478946}
# 100%|██████████| 2209/2209 [01:45<00:00, 20.88it/s]
#   0%|          | 2/2209 [00:00<02:13, 16.53it/s]
# {'ner': 3793.0215544042867}
# 100%|██████████| 2209/2209 [01:37<00:00, 22.61it/s]
#   0%|          | 2/2209 [00:00<02:17, 16.07it/s]
# {'ner': 3632.2598790434517}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.21it/s]
#   0%|          | 3/2209 [00:00<01:34, 23.45it/s]
# {'ner': 3454.291831511156}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.09it/s]
#   0%|          | 3/2209 [00:00<01:43, 21.40it/s]
# {'ner': 3324.6059806620833}
# 100%|██████████| 2209/2209 [01:39<00:00, 22.25it/s]
#   0%|          | 3/2209 [00:00<01:34, 23.31it/s]
# {'ner': 3132.6354799212972}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.04it/s]
#   0%|          | 3/2209 [00:00<01:33, 23.53it/s]
# {'ner': 3008.337826971755}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.17it/s]
#   0%|          | 3/2209 [00:00<01:35, 23.12it/s]
# {'ner': 2999.6819350341384}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.09it/s]
#   0%|          | 3/2209 [00:00<01:32, 23.80it/s]
# {'ner': 2827.67689145681}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.23it/s]
#   0%|          | 3/2209 [00:00<01:38, 22.35it/s]
# {'ner': 2783.528827411639}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.17it/s]
#   0%|          | 3/2209 [00:00<01:37, 22.66it/s]
# {'ner': 2708.6090359373134}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.06it/s]
#   0%|          | 3/2209 [00:00<01:34, 23.43it/s]
# {'ner': 2623.9558293887076}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.03it/s]
#   0%|          | 2/2209 [00:00<01:55, 19.11it/s]
# {'ner': 2397.5073310528087}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.10it/s]
#   0%|          | 3/2209 [00:00<01:31, 24.13it/s]
# {'ner': 2375.9285068143204}
# 100%|██████████| 2209/2209 [01:36<00:00, 22.95it/s]
#   0%|          | 3/2209 [00:00<01:33, 23.70it/s]
# {'ner': 2372.1277097473735}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.18it/s]
#   0%|          | 2/2209 [00:00<01:54, 19.19it/s]
# {'ner': 2258.790973002139}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.08it/s]
#   0%|          | 3/2209 [00:00<01:36, 22.90it/s]
# {'ner': 2165.6616456000256}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.19it/s]
#   0%|          | 3/2209 [00:00<01:31, 24.23it/s]
# {'ner': 2087.1514674381065}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.21it/s]
#   0%|          | 3/2209 [00:00<01:34, 23.44it/s]
# {'ner': 1987.941106880923}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.12it/s]
#   0%|          | 3/2209 [00:00<01:32, 23.78it/s]
# {'ner': 2024.7600668281443}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.02it/s]
#   0%|          | 3/2209 [00:00<01:33, 23.53it/s]
# {'ner': 2001.254650743472}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.01it/s]
#   0%|          | 3/2209 [00:00<01:37, 22.66it/s]
# {'ner': 1923.5555158444035}
# 100%|██████████| 2209/2209 [01:35<00:00, 23.14it/s]
#   0%|          | 3/2209 [00:00<01:30, 24.27it/s]
# {'ner': 1883.3334529966503}
#  22%|██▏       | 492/2209 [00:21<01:12, 23.73it/s]

# %% [markdown]
# ## Saving of the Model

# %%
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)

# %% [markdown]
# # Loading and using the created model on new data

# %%
corpora_validation = corpora = extract_articles_content("path_to_the_scientific_articles_test_folder")

# %%
nlp_validation = spacy.load("the value of output_dir = Pathpath_to_the_folder_where_we_save_the_model")
doc_validation = nlp_validation(corpora_validation)
spacy.displacy.render(doc_validation, style="ent", jupyter=True)

# %%
annot(corpora_validation, silver)

# %%
nlp_validation = spacy.load("en_core_web_sm")
doc_validation = nlp_validation(corpora_validation[0])

for token in doc_validation:
   print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop + len(token.text) - 1)

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this project, we learned to recognize from a set of documents, the entities belonging to a specific domain by using the basic principles of terminology. To optimize the result, we can increase the number of epochs.
